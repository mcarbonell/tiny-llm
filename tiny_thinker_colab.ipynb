# %% [markdown]
# # 🚀 TinyThinker - Google Colab Setup
#
# Este cuaderno está preconfigurado para facilitar el entrenamiento de los modelos de **TinyThinker** usando las GPUs gratuitas o de pago de Google Colab.
#
# **Pasos iniciales:**
# 1. Ve a `Entorno de ejecución` > `Cambiar tipo de entorno de ejecución` y asegúrate de seleccionar un acelerador por Hardware (T4, L4 o A100 GPU).
# 2. Ejecuta las celdas en orden.

# %% [markdown]
# ### 1. Montar Google Drive
# Como el almacenamiento de Colab es efímero, necesitamos montar Google Drive para guardar los checkpoints de los modelos (`.pt`) y no perder horas de entrenamiento si la sesión se desconecta.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Crear una carpeta en Drive para guardar los checkpoints de TinyThinker si no existe
# !mkdir -p /content/drive/MyDrive/tiny-thinker/checkpoints
print("\u2705 Drive montado y carpeta de checkpoints lista.")
# Out:
# Mounted at /content/drive
# ✅ Drive montado y carpeta de checkpoints lista.

# %% [markdown]
# ### 2. Clonar el repositorio e instalar dependencias
# Reemplaza `URL_DEL_REPO` con la URL real de tu repositorio en GitHub. Si tu repositorio es privado, tendrás que usar un Personal Access Token (PAT) en la URL, por ejemplo: `https://TU_USUARIO:TU_TOKEN@github.com/usuario/tiny-thinker.git`

# %%
import os

# --- CONFIGURACIÓN ---
REPO_URL = "https://github.com/TU_USUARIO/tiny-thinker.git" # <-- CAMBIA ESTO
# ---------------------

if not os.path.exists('/content/tiny-thinker'):
    # !git clone {REPO_URL} /content/tiny-thinker
else:
    print("\u2139\ufe0f El repositorio ya está clonado. Actualizando...")
    # %cd /content/tiny-thinker
    # !git pull

# %cd /content/tiny-thinker

print("\n\u23f3 Instalando dependencias...")
# !pip install -r requirements.txt -q
print("\u2705 Dependencias instaladas.")

# %% [markdown]
# ### 3. (Opcional) Preparar o descargar los datos
# Si no subiste la carpeta `data/` a GitHub por ser muy pesada, debes regenerar los binarios o descargarlos desde tu Drive.

# %%
# Si necesitas regenerar los datos usando los scripts locales:
# !python scripts/prepare_data.py

# Alternativa: Si tienes tu dataset (ej. train_v1.bin) en Google Drive, cópialo al entorno local para mayor velocidad:
# !mkdir -p data
# !cp /content/drive/MyDrive/tiny-thinker/data/train_v1.bin data/
# print("\u2705 Datos copiados desde Drive a local.")

# %% [markdown]
# ### 4. Lanzar el Entrenamiento 🏋️‍♂️
# Lanza el entrenamiento usando el archivo de configuración que desees.
#
# **⚠️ IMPORTANTE:** Asegúrate de que el archivo YAML de configuración (`configs/...yaml`) o los argumentos del script estén configurados para guardar los checkpoints en `/content/drive/MyDrive/tiny-thinker/checkpoints/` en lugar de la carpeta local por defecto.

# %%
# Ejemplo de entrenamiento (modifica el config según lo que necesites probar hoy)
# !python scripts/finetune.py --config configs/train_spectral_nano.yaml --out_dir /content/drive/MyDrive/tiny-thinker/checkpoints/
